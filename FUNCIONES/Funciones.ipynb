# %%
from datetime import datetime
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---

# %% [markdown]
# # Columnas Categoricas

# %%
df = pd.read_csv("../datos/hr_raw_data_final.csv", index_col = 0)

# %%
df.dtypes
# Out:
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# standardhours                object
# stockoptionlevel              int64
# totalworkingyears            object
# trainingtimeslastyear         int64
# worklifebalance              object
# yearsatcompany                int64
# yearsincurrentrole           object
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome          object
# datebirth                     int64
# salary                       object
# roledepartament              object
# numberchildren              float64
# remotework                   object
# dtype: object

# %%
def buscar_columnas_categoricas(df):
    """
    Busca y devuelve las columnas de tipo categórico en un DataFrame.

    Parámetros:
    - df (pd.DataFrame): El DataFrame en el que se buscarán columnas categóricas.

    Retorna:
    - list: Lista de nombres de columnas que son de tipo categórico.
    """
    # Verifica si las columnas son del tipo 'category' o de tipo 'object' (usualmente usadas para categóricos)
    columnas_categoricas = df.select_dtypes(include=['O']).columns.tolist()
    return columnas_categoricas

# %%
print(f"Columnas categoricas: {buscar_columnas_categoricas(df)}")
# Out:
# Columnas categoricas: ['age', 'attrition', 'businesstravel', 'department', 'educationfield', 'jobrole', 'maritalstatus', 'monthlyincome', 'monthlyrate', 'over18', 'overtime', 'performancerating', 'standardhours', 'totalworkingyears', 'worklifebalance', 'yearsincurrentrole', 'sameasmonthlyincome', 'salary', 'roledepartament', 'remotework']

# %% [markdown]
# ---

# %% [markdown]
# # Transformación de los NAN

# %%
"""def transformar_nan_sql(df, columna=None, valor_reemplazo='NULL'):
    
    Reemplaza los valores NaN en una columna específica o en todas las columnas 
    de un DataFrame con un valor compatible con SQL.

    Parámetros:
    - df (pd.DataFrame): El DataFrame en el que se reemplazarán los NaN.
    - columna (str, opcional): El nombre de la columna donde se reemplazarán los NaN. 
                               Si es None, reemplazará en todas las columnas.
    - valor_reemplazo: El valor con el que se reemplazarán los NaN. Ejemplo: 'NULL', '', 0.

    Retorna:
    - pd.DataFrame: El DataFrame con los NaN reemplazados.
    
    if columna:
        # Si se especifica una columna, verifica que exista
        if columna not in df.columns:
            raise ValueError(f"La columna '{columna}' no existe en el DataFrame.")
        # Reemplaza los NaN en la columna específica
        df[columna] = df[columna].replace({np.nan: valor_reemplazo})
    else:
        # Reemplaza los NaN en todas las columnas
        df = df.replace({np.nan: valor_reemplazo})
    
    return df"""
# Out:
# 'def transformar_nan_sql(df, columna=None, valor_reemplazo=\'NULL\'):\n    \n    Reemplaza los valores NaN en una columna específica o en todas las columnas \n    de un DataFrame con un valor compatible con SQL.\n\n    Parámetros:\n    - df (pd.DataFrame): El DataFrame en el que se reemplazarán los NaN.\n    - columna (str, opcional): El nombre de la columna donde se reemplazarán los NaN. \n                               Si es None, reemplazará en todas las columnas.\n    - valor_reemplazo: El valor con el que se reemplazarán los NaN. Ejemplo: \'NULL\', \'\', 0.\n\n    Retorna:\n    - pd.DataFrame: El DataFrame con los NaN reemplazados.\n    \n    if columna:\n        # Si se especifica una columna, verifica que exista\n        if columna not in df.columns:\n            raise ValueError(f"La columna \'{columna}\' no existe en el DataFrame.")\n        # Reemplaza los NaN en la columna específica\n        df[columna] = df[columna].replace({np.nan: valor_reemplazo})\n    else:\n        # Reemplaza los NaN en todas las columnas\n        df = df.replace({np.nan: valor_reemplazo})\n    \n    return df'

# %%
"""# Reemplazar los NaN en una columna específica
transformar_nan_sql(df, columna="educationfield", valor_reemplazo='NULL')
transformar_nan_sql(df, columna="department", valor_reemplazo='NULL')
transformar_nan_sql(df, columna="maritalstatus", valor_reemplazo='NULL')
transformar_nan_sql(df, columna="overtime", valor_reemplazo='NULL')
transformar_nan_sql(df, columna="roledepartament", valor_reemplazo='NULL')"""
# Out:
# '# Reemplazar los NaN en una columna específica\ntransformar_nan_sql(df, columna="educationfield", valor_reemplazo=\'NULL\')\ntransformar_nan_sql(df, columna="department", valor_reemplazo=\'NULL\')\ntransformar_nan_sql(df, columna="maritalstatus", valor_reemplazo=\'NULL\')\ntransformar_nan_sql(df, columna="overtime", valor_reemplazo=\'NULL\')\ntransformar_nan_sql(df, columna="roledepartament", valor_reemplazo=\'NULL\')'

# %%
# Reemplazar los NaN en todas las columnas
##transformar_nan_sql(df, valor_reemplazo='NULL')

# %%
df.head(2)
# Out:
#   age attrition businesstravel    dailyrate department  distancefromhome  \
# 0  51        No            NaN  2015.722222        NaN                 6
# 1  52        No            NaN  2063.388889        NaN                 1
#
#    education educationfield  employeecount  employeenumber  \
# 0          3            NaN              1               1
# 1          4  Life Sciences              1               2
#
#    environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 0                        1       0         NaN               3         5
# 1                        3       0         NaN               2         5
#
#                jobrole  jobsatisfaction maritalstatus monthlyincome  \
# 0   resEArch DIREcToR                 3           NaN     16280,83$
# 1             ManAGeR                 3           NaN           NaN
#
#   monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0   42330,17$                   7      Y       No                 13
# 1   43331,17$                   0    NaN      NaN                 14
#
#   performancerating  relationshipsatisfaction standardhours  stockoptionlevel  \
# 0               3,0                         3     Full Time                 0
# 1               3,0                         1           NaN                 1
#
#   totalworkingyears  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   sameasmonthlyincome  datebirth      salary roledepartament  numberchildren  \
# 0           16280,83$       1972  195370,00$             NaN             NaN
# 1                 NaN       1971  199990,00$             NaN             NaN
#
#   remotework
# 0        Yes
# 1          1

# %%
# Crear función de conversión de números a numeros absolutos

def convertir_a_absoluto(numero):
    """
    Convierte un número a su valor absoluto.

    Parámetros:
    numero (int | float): Número a convertir.

    Retorno:
    int | float: Valor absoluto del número.
    """
    return abs(numero)

# Ejemplo de uso
print(convertir_a_absoluto(-5))      
print(convertir_a_absoluto(-3.14))
# Out:
# 5
# 3.14

# %%
df["distancefromhome"] = df["distancefromhome"].apply(convertir_a_absoluto)

# %%
# Crear función para transformar float a string

def float_a_string(dato):
    """
    Convierte un número float a string.
    
    Parámetros:
    dato (float): Número a convertir.
    
    Retorno:
    str: Representación del número en formato string.
    """
    return str(dato)

# Ejemplo de uso
resultado = float_a_string(123.456)
print(resultado)
# Out:
# 123.456

# %%
type(resultado)
# Out:
# str

# %%
# Crear función para transformar string a int. No esta hecho para las columnas adecuadas. 

"""def string_a_int (dato):
    try:
        return int (dato)
    except:
        return np.nan
columns = [ 'salary']
for col in columns:
    df[col] = df[col].apply(string_a_int)

# Ejemplo de uso
df['salary']"""
# Out:
# "def string_a_int (dato):\n    try:\n        return int (dato)\n    except:\n        return np.nan\ncolumns = [ 'salary']\nfor col in columns:\n    df[col] = df[col].apply(string_a_int)\n\n# Ejemplo de uso\ndf['salary']"

# %%
def cambiar_coma_punto(columna):
    """
    Cambia las comas por puntos y elimina símbolos como '$' en los valores de una columna.
    Parámetros:
        columna (str): Cadena de texto a modificar.
    Retorna:
        float: Número transformado, o np.nan si ocurre un error.
    """
    #if isinstance(columna, (int, float)):
            #return columna
    try:
        # Reemplazar comas por puntos y eliminar el símbolo '$'
        return float(columna.replace(',', '.').replace('$', ''))
    except:
        # Si hay un error (como valores no numéricos), devolver NaN
        return np.nan
columnas = ["totalworkingyears", "worklifebalance", "yearsincurrentrole", "monthlyincome", "monthlyrate", "sameasmonthlyincome", "salary","performancerating"]
# Aplicar la transformación
for col in columnas:
    if col in df.columns:
        df[col] = df[col].apply(cambiar_coma_punto)
df.head(30)
# Out:
#    age attrition     businesstravel    dailyrate                department  \
# 0   51        No                NaN  2015.722222                       NaN
# 1   52        No                NaN  2063.388889                       NaN
# 2   42        No      travel_rarely  1984.253968   Research & Development
# 3   47        No      travel_rarely  1771.404762                       NaN
# 4   46        No                NaN  1582.771346                       NaN
# 5   48        No                NaN  1771.920635   Research & Development
# 6   59        No                NaN  1032.487286                       NaN
# 7   42        No      travel_rarely   556.256661                       NaN
# 8   41        No                NaN  1712.182540                       NaN
# 9   41        No  travel_frequently  1973.984127                       NaN
# 10  41        No         non-travel  2060.706349                       NaN
# 11  56        No      travel_rarely  1382.746032                       NaN
# 12  38        No                NaN  1362.523810                       NaN
# 13  41       Yes      travel_rarely  2016.547619                       NaN
# 14  55        No                NaN  1973.984127                       NaN
# 15  40        No      travel_rarely  1861.373016                       NaN
# 16  58       Yes      travel_rarely  1985.698413                       NaN
# 17  46        No      travel_rarely  1582.771346                       NaN
# 18  35        No                NaN   556.256661                       NaN
# 19  40        No      travel_rarely  1032.487286                       NaN
# 20  45        No         non-travel  1108.920635   Research & Development
# 21  33        No                NaN  1032.487286                       NaN
# 22  36        No                NaN  1032.487286                       NaN
# 23  47        No                NaN  1728.380952                       NaN
# 24  36        No      travel_rarely   639.785714                       NaN
# 25  35        No                NaN  1032.487286                       NaN
# 26  52       Yes                NaN  2047.500000                       NaN
# 27  36        No                NaN   556.256661                       NaN
# 28  33        No      travel_rarely   556.256661                       NaN
# 29  34        No         non-travel   412.801587                    Sales
#
#     distancefromhome  education    educationfield  employeecount  \
# 0                  6          3               NaN              1
# 1                  1          4     Life Sciences              1
# 2                  4          2  Technical Degree              1
# 3                  2          4           Medical              1
# 4                  3          3  Technical Degree              1
# 5                 22          3           Medical              1
# 6                 25          3     Life Sciences              1
# 7                  1          1               NaN              1
# 8                  2          5               NaN              1
# 9                  9          3               NaN              1
# 10                 7          1               NaN              1
# 11                23          3     Life Sciences              1
# 12                10          3           Medical              1
# 13                12          3               NaN              1
# 14                14          4           Medical              1
# 15                 2          4               NaN              1
# 16                 2          4               NaN              1
# 17                 2          3               NaN              1
# 18                13          5     Life Sciences              1
# 19                15          3     Life Sciences              1
# 20                 1          1               NaN              1
# 21                 1          2     Life Sciences              1
# 22                 8          3               NaN              1
# 23                 2          2             Other              1
# 24                42          2     Life Sciences              1
# 25                 9          3     Life Sciences              1
# 26                 2          1               NaN              1
# 27                 2          4     Life Sciences              1
# 28                28          4     Life Sciences              1
# 29                10          3     Life Sciences              1
#
#     employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0                1                        1       0         NaN
# 1                2                        3       0         NaN
# 2                3                        3       0         NaN
# 3                4                        1       1         NaN
# 4                5                        1       1         NaN
# 5                6                        4       1         NaN
# 6                7                        1       1         NaN
# 7                8                        2       0   69.532083
# 8                9                        2       1         NaN
# 9               10                        1       0         NaN
# 10              11                        2       1         NaN
# 11              12                        4       0  172.843254
# 12              13                        2       1         NaN
# 13              14                        2       1         NaN
# 14              15                        3       0         NaN
# 15              16                        3       1         NaN
# 16              17                        4       0         NaN
# 17              18                        3       1         NaN
# 18              19                        2       0         NaN
# 19              20                        1       1         NaN
# 20              21                        3       0         NaN
# 21              22                        1       1         NaN
# 22              23                        3       1         NaN
# 23              24                        3       1  216.047619
# 24              25                       42       0   79.973214
# 25              26                        4       1  129.060911
# 26              27                        1       1         NaN
# 27              28                        3       1         NaN
# 28              29                        2       0   69.532083
# 29              30                        4       0         NaN
#
#     jobinvolvement  joblevel                      jobrole  jobsatisfaction  \
# 0                3         5           resEArch DIREcToR                 3
# 1                2         5                     ManAGeR                 3
# 2                3         5                     ManaGER                 4
# 3                3         4           ReseArCH DIrECtOr                 3
# 4                4         4             sAleS EXECUtIve                 1
# 5                3         4                     MANAger                 4
# 6                3         3             Sales ExeCutIVe                 1
# 7                3         2             Sales eXEcUTiVe                 3
# 8                3         4                     mANAGEr                 1
# 9                3         5           reSEaRCH DIrectoR                 3
# 10               1         5           RESeArcH DIrEctoR                 3
# 11               3         4      MANUfACturing DIReCtOr                 2
# 12               1         3           REseaRCh dirEcToR                 3
# 13               3         5           reseARCh DIrEctoR                 3
# 14               4         5           RESeaRCH dirEctor                 2
# 15               3         5                     MAnAgeR                 3
# 16               3         5           reSeARCh DIrEcToR                 2
# 17               3         4                     MAnaGER                 1
# 18               4         2          REseArcH sciENtiST                 1
# 19               2         3      MAnUFaCtUring dIRecTOr                 3
# 20               2         3   heaLtHcArE repResENtATiVe                 3
# 21               3         3           RESEARCH dIrECtor                 4
# 22               3         3   hEaltHCarE ReprESENTAtIvE                 3
# 23               3         4                     maNagEr                 4
# 24               3         2             SALEs exeCUtIVe                 4
# 25               2         3      manUfACtURing dirEctOR                 3
# 26               1         5                     mAnageR                 4
# 27               3         2      MaNufActURing dIrecTOr                 2
# 28               3         2       laBoratOry tecHNiCiaN                 3
# 29               3         2             saLEs exEcutIVe                 3
#
#    maritalstatus  monthlyincome  monthlyrate  numcompaniesworked over18  \
# 0            NaN       16280.83     42330.17                   7      Y
# 1            NaN            NaN     43331.17                   0    NaN
# 2        Married            NaN     41669.33                   1    NaN
# 3        Married       14307.50     37199.50                   3      Y
# 4       Divorced       12783.92     33238.20                   2      Y
# 5            NaN       14311.67     37210.33                   3    NaN
# 6            NaN        8339.32     21682.23                   7      Y
# 7        Married            NaN     11681.39                   1    NaN
# 8        Married       13829.17     35955.83                   7    NaN
# 9            NaN       15943.72     41453.67                   2    NaN
# 10           NaN       16644.17     43274.83                   1      Y
# 11       Married            NaN     29037.67                   4    NaN
# 12       Married            NaN     28613.00                   3      Y
klifebalance  yearsatcompany  yearsincurrentrole  \
# 0               3.0              20                 NaN
# 1               3.0              33                 NaN
# 2               NaN              22                 NaN
# 3               NaN              20                 NaN
# 4               3.0              19                 NaN
# 5               3.0              22                 NaN
# 6               2.0              21                 NaN
# 7               3.0              20                 NaN
# 8               3.0              18                 NaN
# 9               4.0              18                 NaN
# 10              3.0              21                 NaN
# 11              3.0              19                 NaN
# 12              3.0              18                 NaN
# 13              3.0              22                 NaN
# 14              3.0              24                 NaN
# 15              3.0              20                 NaN
# 16              3.0              31                 NaN
# 17              3.0              26                 NaN
# 18              3.0              16                 NaN
# 19              NaN              18                 NaN
# 20              2.0              23                 NaN
# 21              3.0              15                 NaN
# 22              3.0              17                 NaN
# 23              2.0              26                 NaN
# 24              NaN              18                 NaN
# 25              3.0              17                 NaN
# 26              3.0              32                 NaN
# 27              3.0              16                 NaN
# 28              3.0              15                 NaN
# 29              3.0              15                 NaN
#
#     yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                        15                    15             16280.83
# 1                        11                     9                  NaN
# 2                        11                    15                  NaN
# 3                         5                     6             14307.50
# 4                         2                     8             12783.92
# 5                         4                     7             14311.67
# 6                         7                     9              8339.32
# 7                        11                     6                  NaN
# 8                        11                     8             13829.17
# 9                         0                    11             15943.72
# 10                        5                    10             16644.17
# 11                       15                     9                  NaN
# 12                        1                    11                  NaN
# 13                       15                     8                  NaN
# 14                        2                    15             15943.72
# 15                        1                    12             15034.17
# 16                       13                     8             16038.33
# 17                       15                     9             12783.92
# 18                        1                    10              4492.84
# 19                       14                    12              8339.32
# 20                       14                     4              8956.67
# 21                        8                    12                  NaN
# 22                       12                     8                  NaN
# 23                        3                     0                  NaN
# 24                        4                    11              5167.50
# 25                        5                    15                  NaN
# 26                        6                     9                  NaN
# 27                        5                    12              4492.84
# 28                        5                     7              4492.84
# 29                        0                     7              3334.17
#
#     datebirth     salary                                    roledepartament  \
# 0        1972  195370.00                                                NaN
# 1        1971  199990.00                                                NaN
# 2        1981  192320.00                ManaGER  -  Research & Development
# 3        1976  171690.00                                                NaN
# 4        1977        NaN                                                NaN
# 5        1975        NaN                MANAger  -  Research & Development
# 6        1964  100071.84                                                NaN
# 7        1981   53914.11                                                NaN
# 8        1982  165950.00                                                NaN
# 9        1982        NaN                                                NaN
# 10       1982  199730.00                                                NaN
# 11       1967  134020.00                                                NaN
# 12       1985  132060.00                                                NaN
# 13       1982  195450.00                                                NaN
# 14       1968        NaN                                                NaN
# 15       1983  180410.00                                                NaN
# 16       1965  192460.00                                                NaN
# 17       1977        NaN                                                NaN
# 18       1988        NaN                                                NaN
# 19       1983        NaN                                                NaN
# 20       1978  107480.00   heaLtHcArE repResENtATiVe  -  Research & Deve...
# 21       1990  100071.84                                                NaN
# 22       1987  100071.84                                                NaN
# 23       1976  167520.00                                                NaN
# 24       1987   62010.00                                                NaN
# 25       1988  100071.84                                                NaN
# 26       1971  198450.00                                                NaN
# 27       1987   53914.11                                                NaN
# 28       1990   53914.11                                                NaN
# 29       1989   40010.00                         saLEs exEcutIVe  -  Sales
#
#     numberchildren remotework
# 0              NaN        Yes
# 1              NaN          1
# 2              NaN          1
# 3              NaN      False
# 4              NaN          0
# 5              NaN        Yes
# 6              NaN       True
# 7              NaN          0
# 8              NaN       True
# 9              NaN          0
# 10             NaN          0
# 11             NaN      False
# 12             NaN          1
# 13             NaN      False
# 14             NaN       True
# 15             NaN          0
# 16             NaN          0
# 17             NaN      False
# 18             NaN      False
# 19             NaN       True
# 20             NaN      False
# 21             NaN       True
# 22             NaN          1
# 23             NaN      False
# 24             NaN       True
# 25             NaN      False
# 26             NaN          1
# 27             NaN          0
# 28             NaN        Yes
# 29             NaN          1

# %%
# Quedarse con el Primer Dígito de un Número de Dos Dígitos:
def primer_digito(df, column):
    df[column] = df[column].astype(str).str[0].astype(int)
    return df
# Uso:
df = primer_digito(df, 'environmentsatisfaction')

# %%
df['environmentsatisfaction'].unique()
# Out:
# array([1, 3, 4, 2])

# %%
def convertir_valores(valor):
    """
    Convierte los valores: 0 a 'yes', 1 a 'no', y deja el resto sin cambios
    Parámetros:
        valor: Valor a transformar (puede ser numérico o texto).
    Retorna:
        string: Valor transformado, o np.nan si ocurre un error.
    """
    try:
        valor_str = str(valor).strip()  # Convertir a cadena y eliminar espacios en blanco
        if valor_str == "0":  # Comparar como cadena
            return 'm'.title()
        elif valor_str == "1":  # Comparar como cadena
            return 'f'.title()
        else:
        
            return valor  # Si no es '0' ni '1', dejar el valor sin cambios
    except Exception as e:
        print(f"Error al procesar el valor {valor}: {e}")
        return np.nan  # Manejar errores con np.nan
# Aplicar la función
df["gender"] = df["gender"].apply(convertir_valores)
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  environmentsatisfaction gender  hourlyrate  jobinvolvement  \
# 0               1                        1      M         NaN               3
# 1               2                        3      M         NaN               2
# 2               3                        3      M         NaN               3
# 3               4                        1      F         NaN               3
# 4               5                        1      F         NaN               4
#
#    joblevel              jobrole  jobsatisfaction maritalstatus  \
# 0         5   resEArch DIREcToR                 3           NaN
# 1         5             ManAGeR                 3           NaN
# 2         5             ManaGER                 4       Married
# 3         4   ReseArCH DIrECtOr                 3       Married
# 4         4     sAleS EXECUtIve                 1      Divorced
#
#    monthlyincome  monthlyrate  numcompaniesworked over18 overtime  \
# 0       16280.83     42330.17                   7      Y       No
# 1            NaN     43331.17                   0    NaN      NaN
# 2            NaN     41669.33                   1    NaN       No
# 3       14307.50     37199.50                   3      Y      NaN
# 4       12783.92     33238.20                   2      Y       No
#
#    percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                 13                3.0                         3
# 1                 14                3.0                         1
# 2                 11                3.0                         4
# 3                 19                3.0                         2
# 4                 12                3.0                         4
#
#   standardhours  stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0     Full Time                 0                NaN                      5
# 1           NaN                 1               34.0                      5
# 2           NaN                 0               22.0                      3
# 3     Full Time                 2                NaN                      2
# 4           NaN                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary                       roledepartament  numberchildren  \
# 0       1972  195370.0                                   NaN             NaN
# 1       1971  199990.0                                   NaN             NaN
# 2       1981  192320.0   ManaGER  -  Research & Development              NaN
# 3       1976  171690.0                                   NaN             NaN
# 4       1977       NaN                                   NaN             NaN
#
#   remotework
# 0        Yes
# 1          1
# 2          1
# 3      False
# 4          0

# %%
x = ["jobrole", "roledepartament",]

def corregir_y_minusculas(df, columna):
    # Verifica si la columna existe en el DataFrame
    if columna in df.columns:
        # Itera sobre las filas y corrige los valores
        corrected_values = []
        for value in df[columna]:
            if pd.notnull(value):  # Si el valor no es nulo
                corrected_values.append(str(value).strip().lower())  # Corrige y convierte a minúsculas
            else:
                corrected_values.append(value)  # Deja los valores nulos como están
        # Asigna los valores corregidos a la columna
        df[columna] = corrected_values
    else:
        raise ValueError(f"La columna {columna} no existe en el DataFrame.")
    return df

# %%
x = ["jobrole", "roledepartament", "educationfield","department","maritalstatus","standardhours",]

for columna in x:
    corregir_y_minusculas(df,columna)

df.head()
# Out:
#   age attrition businesstravel    dailyrate              department  \
# 0  51        No            NaN  2015.722222                     NaN
# 1  52        No            NaN  2063.388889                     NaN
# 2  42        No  travel_rarely  1984.253968  research & development
# 3  47        No  travel_rarely  1771.404762                     NaN
# 4  46        No            NaN  1582.771346                     NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     life sciences              1
# 2                 4          2  technical degree              1
# 3                 2          4           medical              1
# 4                 3          3  technical degree              1
#
#    employeenumber  environmentsatisfaction gender  hourlyrate  jobinvolvement  \
# 0               1                        1      M         NaN               3
# 1               2                        3      M         NaN               2
# 2               3                        3      M         NaN               3
# 3               4                        1      F         NaN               3
# 4               5                        1      F         NaN               4
#
#    joblevel            jobrole  jobsatisfaction maritalstatus  monthlyincome  \
# 0         5  research director                3           NaN       16280.83
# 1         5            manager                3           NaN            NaN
# 2         5            manager                4       married            NaN
# 3         4  research director                3       married       14307.50
# 4         4    sales executive                1      divorced       12783.92
#
#    monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0     42330.17                   7      Y       No                 13
# 1     43331.17                   0    NaN      NaN                 14
# 2     41669.33                   1    NaN       No                 11
# 3     37199.50                   3      Y      NaN                 19
# 4     33238.20                   2      Y       No                 12
#
#    performancerating  relationshipsatisfaction standardhours  \
# 0                3.0                         3     full time
# 1                3.0                         1           NaN
# 2                3.0                         4           NaN
# 3                3.0                         2     full time
# 4                3.0                         4           NaN
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary                     roledepartament  numberchildren  \
# 0       1972  195370.0                                 NaN             NaN
# 1       1971  199990.0                                 NaN             NaN
# 2       1981  192320.0  manager  -  research & development             NaN
# 3       1976  171690.0                                 NaN             NaN
# 4       1977       NaN                                 NaN             NaN
#
#   remotework
# 0        Yes
# 1          1
# 2          1
# 3      False
# 4          0

# %%
df["roledepartament"].unique()
# Out:
# array([nan, 'manager  -  research & development',
#        'healthcare representative  -  research & development',
#        'sales executive  -  sales',
#        'laboratory technician  -  research & development',
#        'manufacturing director  -  research & development',
#        'research scientist  -  research & development',
#        'research director  -  research & development',
#        'human resources  -  human resources', 'manager  -  sales',
#        'sales representative  -  sales', 'manager  -  human resources'],
#       dtype=object)

# %%
# Verificar los tipos de datos de las columnas
print(df["dailyrate"].dtypes)
# Out:
# float64

# %%
#Crear función para redondeo 
columnas_redondeo = ["dailyrate"]

def cambio_round (dato):
    return dato.round().astype(float)

for col in columnas_redondeo:
    df[col] = df[col].round(2)  # Redondear directamente

#for col in columnas_redondeo:
    #df[col] = df[col].apply(cambio_round)

# %%
df["dailyrate"].head()
# Out:
# 0    2015.72
# 1    2063.39
# 2    1984.25
# 3    1771.40
# 4    1582.77
# Name: dailyrate, dtype: float64

# %%
df["performancerating"].unique()
# Out:
# array([ 3.,  4., nan])

# %%
df.head()
# Out:
#   age attrition businesstravel  dailyrate              department  \
# 0  51        No            NaN    2015.72                     NaN
# 1  52        No            NaN    2063.39                     NaN
# 2  42        No  travel_rarely    1984.25  research & development
# 3  47        No  travel_rarely    1771.40                     NaN
# 4  46        No            NaN    1582.77                     NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     life sciences              1
# 2                 4          2  technical degree              1
# 3                 2          4           medical              1
# 4                 3          3  technical degree              1
#
#    employeenumber  environmentsatisfaction gender  hourlyrate  jobinvolvement  \
# 0               1                        1      M         NaN               3
# 1               2                        3      M         NaN               2
# 2               3                        3      M         NaN               3
# 3               4                        1      F         NaN               3
# 4               5                        1      F         NaN               4
#
#    joblevel            jobrole  jobsatisfaction maritalstatus  monthlyincome  \
# 0         5  research director                3           NaN       16280.83
# 1         5            manager                3           NaN            NaN
# 2         5            manager                4       married            NaN
# 3         4  research director                3       married       14307.50
# 4         4    sales executive                1      divorced       12783.92
#
#    monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0     42330.17                   7      Y       No                 13
# 1     43331.17                   0    NaN      NaN                 14
# 2     41669.33                   1    NaN       No                 11
# 3     37199.50                   3      Y      NaN                 19
# 4     33238.20                   2      Y       No                 12
#
#    performancerating  relationshipsatisfaction standardhours  \
# 0                3.0                         3     full time
# 1                3.0                         1           NaN
# 2                3.0                         4           NaN
# 3                3.0                         2     full time
# 4                3.0                         4           NaN
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary                     roledepartament  numberchildren  \
# 0       1972  195370.0                                 NaN             NaN
# 1       1971  199990.0                                 NaN             NaN
# 2       1981  192320.0  manager  -  research & development             NaN
# 3       1976  171690.0                                 NaN             NaN
# 4       1977       NaN                                 NaN             NaN
#
#   remotework
# 0        Yes
# 1          1
# 2          1
# 3      False
# 4          0

# %%
def convertir_valores(valor):
    """
    Convierte los valores: 0 a 'yes', 1 a 'no', y deja el resto sin cambios
    Parámetros:
        valor: Valor a transformar (puede ser numérico o texto).
    Retorna:
        string: Valor transformado, o np.nan si ocurre un error.
    """
    try:
        valor_str = str(valor).strip()  # Convertir a cadena y eliminar espacios en blanco
        if valor_str == "0":  # Comparar como cadena
            return 'true'.title()
        elif valor_str == "1":  # Comparar como cadena
            return 'false'.title()
        elif valor_str == "Yes":
            return 'true'.title()
        else:
            return valor  # Si no es '0' ni '1', dejar el valor sin cambios
    except Exception as e:
        print(f"Error al procesar el valor {valor}: {e}")
        return np.nan  # Manejar errores con np.nan

# %%
# Aplicar la función
df["remotework"] = df["remotework"].apply(convertir_valores)
df.head()
# Out:
#   age attrition businesstravel  dailyrate              department  \
# 0  51        No            NaN    2015.72                     NaN
# 1  52        No            NaN    2063.39                     NaN
# 2  42        No  travel_rarely    1984.25  research & development
# 3  47        No  travel_rarely    1771.40                     NaN
# 4  46        No            NaN    1582.77                     NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     life sciences              1
# 2                 4          2  technical degree              1
# 3                 2          4           medical              1
# 4                 3          3  technical degree              1
#
#    employeenumber  environmentsatisfaction gender  hourlyrate  jobinvolvement  \
# 0               1                        1      M         NaN               3
# 1               2                        3      M         NaN               2
# 2               3                        3      M         NaN               3
# 3               4                        1      F         NaN               3
# 4               5                        1      F         NaN               4
#
#    joblevel            jobrole  jobsatisfaction maritalstatus  monthlyincome  \
# 0         5  research director                3           NaN       16280.83
# 1         5            manager                3           NaN            NaN
# 2         5            manager                4       married            NaN
# 3         4  research director                3       married       14307.50
# 4         4    sales executive                1      divorced       12783.92
#
#    monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0     42330.17                   7      Y       No                 13
# 1     43331.17                   0    NaN      NaN                 14
# 2     41669.33                   1    NaN       No                 11
# 3     37199.50                   3      Y      NaN                 19
# 4     33238.20                   2      Y       No                 12
#
#    performancerating  relationshipsatisfaction standardhours  \
# 0                3.0                         3     full time
# 1                3.0                         1           NaN
# 2                3.0                         4           NaN
# 3                3.0                         2     full time
# 4                3.0                         4           NaN
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    salary                     roledepartament  numberchildren  \
# 0       1972  195370.0                                 NaN             NaN
# 1       1971  199990.0                                 NaN             NaN
# 2       1981  192320.0  manager  -  research & development             NaN
# 3       1976  171690.0                                 NaN             NaN
# 4       1977       NaN                                 NaN             NaN
#
#   remotework
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True

# %%
df["monthlyincome"].unique()
# Out:
# array([16280.83,      nan, 14307.5 , 12783.92, 14311.67,  8339.32,
#        13829.17, 15943.72, 16644.17, 15034.17, 16038.33,  4492.84,
#         8956.67,  5167.5 ,  3334.17,  8705.83,  2675.  ,  8555.  ,
#         8729.17,  3934.17,  3845.83, 14132.5 ,  8588.33,  4505.  ,
#         4918.33,  4928.33,  5538.33, 11100.  ,  5572.5 , 11560.  ,
#        15870.83, 13345.83,  8010.83,  3588.33, 14205.  ,  4222.5 ,
#         3076.67,  2342.59,  4789.17,  8685.  ,  5289.17,  1956.67,
#        10408.33,  6683.33,  7452.5 , 16060.  ,  4647.5 ,  2242.5 ,
#         6169.17,  7352.5 ,  2982.5 , 14815.83, 15177.5 , 15991.67,
#        15989.17,  8340.  ,  6656.67,  5902.5 ,  3935.83,  2839.17,
#         2440.83, 10025.83, 12855.83,  5135.  ,  4271.67,  8015.83,
#         4175.  , 15860.83,  8666.67,  2327.5 ,  4728.33,  7010.  ,
#         2790.  ,  4424.17,  6378.33, 10673.33,  5488.33,  2099.17,
#        10933.33,  2609.17,  5561.67, 14884.17,  6205.  , 11464.17,
#        13831.67,  2557.5 ,  7700.83,  5393.33,  6934.17,  7148.33,
#         3497.5 ,  8240.  ,  4730.83,  7938.33,  5687.5 ,  3686.67,
#         4534.17,  5061.67,  5143.33,  4670.83,  3599.17,  2970.  ,
#         5217.5 ,  5670.  , 16196.67,  4856.67,  3901.67,  1765.83,
#         4978.33, 11010.  ,  3375.83,  4004.17,  2284.17,  7861.67,
#         4496.67,  9299.17,  4133.33,  7327.5 ,  1846.67,  9760.83,
#         4420.  ,  9252.5 ,  5526.67,  6322.5 ,  3612.5 ,  4983.33,
#         3536.67,  4356.67,  2250.  ,  1971.67,  1940.83,  8604.17,
#         9037.5 ,  5320.83,  3050.  ,  7283.33, 11249.17,  2909.17,
#        20323.33, 12735.67,  5347.33,  8941.83,  4654.  ,  8419.67,
#        14445.17,  4528.33,  4519.67,  4227.17,  6547.67, 21068.67,
#         7340.67,  6582.33,  5031.  ,  6339.67,  9760.83,  6142.5 ,
#        14198.17, 14458.17, 29447.17,  4716.83, 42286.83, 41604.33,
#        21770.67,  5899.83, 14395.33,  6848.83,  3076.67,  2600.  ,
#        11349.  , 21634.17, 34649.33,  5135.  , 14692.17, 14414.83,
#         6177.17, 11392.33,  5364.67,  4950.83,  7470.67,  9875.67,
#         3687.67,  5555.33, 10985.  ,  8190.  , 21285.33,  4069.  ,
#         5070.  ,  4608.5 ,  4404.83, 20804.33, 36025.17,  4513.17,
#         2186.17, 17032.17,  5724.33, 11095.5 ,  5837.  , 11037.  ,
#         4927.  ,  5013.67,  5156.67,  4350.67, 22862.67,  4894.5 ,
#         5228.17,  4595.5 ,  5371.17, 28587.  ,  9019.83,  5633.33,
#        39656.5 , 10350.17,  2279.33,  5332.17,  5624.67, 10244.  ,
#        15927.17, 10326.33,  6125.17,  6181.5 ,  4961.67,  4565.17,
#         4788.33, 28580.5 , 39574.17,  2422.33,  5139.33,  6149.  ,
#        39132.17,  3490.5 , 10330.67,  2760.33,  5548.83,  3386.5 ,
#        13840.67, 18148.  , 10488.83,  4493.67,  6439.33, 14765.83,
#         5828.33, 38061.83,  3399.5 ,  9071.83,  7163.  ,  3018.17,
#        23579.83,  6201.  , 14592.5 , 21138.  , 11470.33,  5280.17,
#         8820.5 ,  6404.67, 10070.67,  6075.33,  5284.5 ,  6188.  ,
#         6354.83,  2363.83, 11160.5 ,  6203.17,  6192.33,  2446.17,
#        42100.5 ])

# %%
df.head()
# Out:
#   age attrition businesstravel  dailyrate              department  \
# 0  51        No            NaN    2015.72                     NaN
# 1  52        No            NaN    2063.39                     NaN
# 2  42        No  travel_rarely    1984.25  research & development
# 3  47        No  travel_rarely    1771.40                     NaN
# 4  46        No            NaN    1582.77                     NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     life sciences              1
# 2                 4          2  technical degree              1
# 3                 2          4           medical              1
# 4                 3          3  technical degree              1
#
#    employeenumber  environmentsatisfaction gender  hourlyrate  jobinvolvement  \
# 0               1                        1      M         NaN               3
# 1               2                        3      M         NaN               2
# 2               3                        3      M         NaN               3
# 3               4                        1      F         NaN               3
# 4               5                        1      F         NaN               4
#
#    joblevel            jobrole  jobsatisfaction maritalstatus  monthlyincome  \
# 0         5  research director                3           NaN       16280.83
# 1         5            manager                3           NaN            NaN
# 2         5            manager                4       married            NaN
# 3         4  research director                3       married       14307.50
# 4         4    sales executive                1      divorced       12783.92
#
#    monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0     42330.17                   7      Y       No                 13
# 1     43331.17                   0    NaN      NaN                 14
# 2     41669.33                   1    NaN       No                 11
# 3     37199.50                   3      Y      NaN                 19
# 4     33238.20                   2      Y       No                 12
#
#    performancerating  relationshipsatisfaction standardhours  \
# 0                3.0                         3     full time
# 1                3.0                         1           NaN
# 2                3.0                         4           NaN
# 3                3.0                         2     full time
# 4                3.0                         4           NaN
#
#    stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0                 0                NaN                      5
# 1                 1               34.0                      5
# 2                 0               22.0                      3
# 3                 2                NaN                      2
# 4                 1                NaN                      5
#
#    worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0              3.0              20                 NaN
# 1              3.0              33                 NaN
# 2              NaN              22                 NaN
# 3              NaN              20                 NaN
# 4              3.0              19                 NaN
#
#    yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                       15                    15             16280.83
# 1                       11                     9                  NaN
# 2                       11                    15                  NaN
# 3                        5                     6             14307.50
# 4                        2                     8             12783.92
#
#    datebirth    sal
#         31.42956349,  59.94444444,  14.07043651,  66.43154762,
#         27.65079365,  26.69642857,  35.99503968,  74.96924603,
#         34.76984127,  29.12103175, 108.23015873, 247.47718254,
#         67.42460317,  34.82142857, 133.15972222])

# %%
current_year = datetime.now().year
df['age'] = current_year - df['datebirth']
df['age']
# Out:
# 0       52
# 1       53
# 2       43
# 3       48
# 4       47
#         ..
# 1673    44
# 1674    48
# 1675    30
# 1676    48
# 1677    33
# Name: age, Length: 1678, dtype: int64

# %%
df["yearsincurrentrole"].unique()
# Out:
# array([nan, 13., 12., 11.,  7.,  6.,  4.,  3.,  2.,  1.,  0.])

# %%
df["yearsincurrentrole"].unique()
# Out:
# array([nan, 13., 12., 11.,  7.,  6.,  4.,  3.,  2.,  1.,  0.])

# %%
x = df["sameasmonthlyincome"] == df["monthlyincome"]

# %%
x.value_counts()
# Out:
# True     1189
# False     489
# dtype: int64

# %%
df['businesstravel'] = df['businesstravel'].replace(np.nan, 'non-travel')

# %%
df["numberchildren"].unique()
# Out:
# array([nan])

# %%
df["remotework"].dtype
# Out:
# dtype('O')

# %%
porc_nulos = (df.isnull().sum() / df.shape[0]) * 100
porc_nulos
# Out:
# age                           0.000000
# attrition                     0.000000
# businesstravel                0.000000
# dailyrate                     0.000000
# department                   81.406436
# distancefromhome              0.000000
# education                     0.000000
# educationfield               46.126341
# employeecount                 0.000000
# employeenumber                0.000000
# environmentsatisfaction       0.000000
# gender                        0.000000
# hourlyrate                   75.506555
# jobinvolvement                0.000000
# joblevel                      0.000000
# jobrole                       0.000000
# jobsatisfaction               0.000000
# maritalstatus                40.226460
# monthlyincome                29.141836
# monthlyrate                   0.000000
# numcompaniesworked            0.000000
# over18                       55.899881
# overtime                     41.477950
# percentsalaryhike             0.000000
# performancerating            11.918951
# relationshipsatisfaction      0.000000
# standardhours                20.917759
# stockoptionlevel              0.000000
# totalworkingyears            32.717521
# trainingtimeslastyear         0.000000
# worklifebalance               6.793802
# yearsatcompany                0.000000
# yearsincurrentrole           97.914184
# yearssincelastpromotion       0.000000
# yearswithcurrmanager          0.000000
# sameasmonthlyincome          29.141836
# datebirth                     0.000000
# salary                       16.984505
# roledepartament              81.406436
# numberchildren              100.000000
# remotework                    0.000000
# dtype: float64

# %%
# Vamos a decidir en base al porcentaje de nulos, si lo sustituimos nan por null, si la mediana/media.
# Hourlyrate y yearsincurrentrole se quedan como null.
# lo convertimos a DataFrame
df_nulos = pd.DataFrame(porc_nulos, columns = ["%_nulos"])
# filtramos el DataFrame para quedarnos solo con aquellas columnas que tengan nulos
df_nulos[df_nulos["%_nulos"] > 0]
# Out:
#                         %_nulos
# department            81.406436
# educationfield        46.126341
# hourlyrate            75.506555
# maritalstatus         40.226460
# monthlyincome         29.141836
# over18                55.899881
# overtime              41.477950
# performancerating     11.918951
# standardhours         20.917759
# totalworkingyears     32.717521
# worklifebalance        6.793802
# yearsincurrentrole    97.914184
# sameasmonthlyincome   29.141836
# salary                16.984505
# roledepartament       81.406436
# numberchildren       100.000000

# %%
df.describe()
# Out:
#                age    dailyrate  distancefromhome    education  employeecount  \
# count  1678.000000  1678.000000       1678.000000  1678.000000         1678.0
# mean     37.952920   668.081168         11.184744     2.932658            1.0
# std       9.154908   470.786402         10.479008     1.024270            0.0
# min      19.000000   104.100000          1.000000     1.000000            1.0
# 25%      31.000000   290.040000          2.000000     2.000000            1.0
# 50%      37.000000   556.260000          8.000000     3.000000            1.0
# 75%      44.000000   971.957500         17.000000     4.000000            1.0
# max      61.000000  2063.390000         49.000000     5.000000            1.0
#
#        employeenumber  environmentsatisfaction  hourlyrate  jobinvolvement  \
# count     1678.000000              1678.000000  411.000000     1678.000000
# mean       809.859952                 2.695471   83.140768        2.740763
# std        467.084867                 1.107083   57.272101        0.710359
# min          1.000000                 1.000000   13.012897        1.000000
# 25%        403.250000                 2.000000   36.254439        2.000000
# 50%        813.500000                 3.000000   69.532083        3.000000
# 75%       1215.750000                 4.000000  116.987103        3.000000
# max       1614.000000                 4.000000  255.963294        4.000000
#
#           joblevel  jobsatisfaction  monthlyincome   monthlyrate  \
# count  1678.000000      1678.000000    1189.000000   1678.000000
# mean      2.064362         2.743147    5676.787065  14029.674648
# std       1.099425         1.105172    6157.859086   9886.532728
# min       1.000000         1.000000    1000.000000   2186.170000
# 25%       1.000000         2.000000    2342.590000   6090.750000
# 50%       2.000000         3.000000    4492.840000  11681.390000
# 75%       3.000000         4.000000    7861.670000  20411.080000
# max       5.000000         4.000000   94083.000000  43331.170000
#
#        numcompaniesworked  percentsalaryhike  performancerating  \
# count         1678.000000        1678.000000        1478.000000
# mean             2.670441          15.154350           3.149526
# std              2.501133           3.649607           0.356727
# min              0.000000          11.000000           3.000000
# 25%              1.000000          12.000000           3.000000
# 50%              2.000000          14.000000           3.000000
# 75%              4.000000          18.000000           3.000000
# max              9.000000          25.000000           4.000000
#
#        relationshipsatisfaction  stockoptionlevel  totalworkingyears  \
# count               1678.000000       1678.000000        1129.000000
# mean                   2.700238          0.787843          11.359610
# std                    1.079494          0.843252           7.807298
# min                    1.000000          0.000000           0.000000
# 25%                    2.000000          0.000000           6.000000
# 50%                    3.000000          1.000000          10.000000
# 75%                    4.000000          1.000000          15.000000
# max                    4.000000          3.000000          40.000000
#
#        trainingtimeslastyear  worklifebalance  yearsatcompany  \
# count            1678.000000      1564.000000     1678.000000
# mean                2.795590         2.759591        7.124553
# std                 1.288657         0.703527        6.173837
# min                 0.000000         1.000000        0.000000
# 25%                 2.000000         2.000000        3.000000
# 50%                 3.000000         3.000000        5.000000
# 75%                 3.000000         3.000000        9.000000
# max                 6.000000         4.000000       40.000000
#
#        yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# count           35.000000              1678.000000           1678.000000
# mean             3.971429                 2.241955              4.200238
# std              3.584983                 3.246554              3.554224
# min              0.000000                 0.000000              0.000000
# 25%              2.000000                 0.000000              2.000000
# 50%              2.000000                 1.000000              3.000000
# 75%              6.500000                 3.000000              7.000000
# max             13.000000                15.000000             17.000000
#
#        sameasmonthlyincome    datebirth         salary  numberchildren
# count          1189.000000  1678.000000    1393.000000             0.0
# mean           5676.787065  1986.047080   65070.911587             NaN
# std            6157.859086     9.154908   45849.510802             NaN
# min            1000.000000  1963.000000   10090.000000             NaN
# 25%            2342.590000  1980.000000   28111.130000             NaN
# 50%            4492.840000  1987.000000   53914.110000             NaN
# 75%            7861.670000  1993.000000   94390.000000             NaN
# max           94083.000000  2005.000000  199990.000000             NaN

# %%
"""def nan_numerica(df, columna=None, valor_reemplazo='NULL'):
    
    Reemplaza los valores NaN en una columna numerica o en todas las columnas 
    de un DataFrame con un valor compatible con SQL.

    Parámetros:
    - df (pd.DataFrame): El DataFrame en el que se reemplazarán los NaN.
    - columna (Int): El nombre de la columna donde se reemplazarán los NaN. 
                               Si es None, reemplazará en todas las columnas.
    - valor_reemplazo: El valor con el que se reemplazarán los NaN. Ejemplo: 'NULL', '', 0.

    Retorna:
    - pd.DataFrame: El DataFrame con los NaN reemplazados.
    
    if columna:
        # Si se especifica una columna, verifica que exista
        if columna not in df.columns:
            raise ValueError(f"La columna '{columna}' no existe en el DataFrame.")
        # Reemplaza los NaN en la columna específica
        df[columna] = df[columna].replace({np.nan: valor_reemplazo})
    else:
        # Reemplaza los NaN en todas las columnas
        df = df.replace({np.nan: valor_reemplazo})
    
    return df
    transformar_nan_sql(df, columna="sameasmonthlyincome", valor_reemplazo='NULL')"""
# Out:
# 'def nan_numerica(df, columna=None, valor_reemplazo=\'NULL\'):\n    \n    Reemplaza los valores NaN en una columna numerica o en todas las columnas \n    de un DataFrame con un valor compatible con SQL.\n\n    Parámetros:\n    - df (pd.DataFrame): El DataFrame en el que se reemplazarán los NaN.\n    - columna (Int): El nombre de la columna donde se reemplazarán los NaN. \n                               Si es None, reemplazará en todas las columnas.\n    - valor_reemplazo: El valor con el que se reemplazarán los NaN. Ejemplo: \'NULL\', \'\', 0.\n\n    Retorna:\n    - pd.DataFrame: El DataFrame con los NaN reemplazados.\n    \n    if columna:\n        # Si se especifica una columna, verifica que exista\n        if columna not in df.columns:\n            raise ValueError(f"La columna \'{columna}\' no existe en el DataFrame.")\n        # Reemplaza los NaN en la columna específica\n        df[columna] = df[columna].replace({np.nan: valor_reemplazo})\n    else:\n        # Reemplaza los NaN en todas las columnas\n        df = df.replace({np.nan: valor_reemplazo})\n    \n    return df\n    transformar_nan_sql(df, columna="sameasmonthlyincome", valor_reemplazo=\'NULL\')'

# %%
df["sameasmonthlyincome"].dtype
# Out:
# dtype('float64')

# %%
# Columna "Over18" todos son mayores de 18, esta columna no es relevante.
x = df["age"] > 18
x.unique()
# Out:
# array([ True])

# %%
df = df.drop(columns="over18")

# %%
df["standardhours"] = df["standardhours"].fillna("full time")

# %%
df
# Out:
#       age attrition businesstravel  dailyrate              department  \
# 0      52        No     non-travel    2015.72                     NaN
# 1      53        No     non-travel    2063.39                     NaN
# 2      43        No  travel_rarely    1984.25  research & development
# 3      48        No  travel_rarely    1771.40                     NaN
# 4      47        No     non-travel    1582.77                     NaN
# ...   ...       ...            ...        ...                     ...
# 1673   44        No     non-travel     488.94                     NaN
# 1674   48        No     non-travel    1973.98                     NaN
# 1675   30        No  travel_rarely     290.04                     NaN
# 1676   48        No  travel_rarely    1032.49                     NaN
# 1677   33        No     non-travel     556.26                     NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     life sciences              1
# 2                    4          2  technical degree              1
# 3                    2          4           medical              1
# 4                    3          3  technical degree              1
# ...                ...        ...               ...            ...
# 1673                26          3           medical              1
# 1674                26          4               NaN              1
# 1675                15          3               NaN              1
# 1676                 4          3     life sciences              1
# 1677                 2          2     life sciences              1
#
#       employeenumber  environmentsatisfaction gender  hourlyrate  \
# 0                  1                        1      M         NaN
# 1                  2                        3      M         NaN
# 2                  3                        3      M         NaN
# 3                  4                        1      F         NaN
# 4                  5                        1      F         NaN
# ...              ...                      ...    ...         ...
# 1673             824                        2      F         NaN
# 1674            1087                        4      F         NaN
# 1675             528                        3      M         NaN
# 1676              76                        3      F         NaN
# 1677             401                        4      F   69.532083
#
#       jobinvolvement  joblevel                 jobrole  jobsatisfaction  \
# 0                  3         5       research director                3
# 1                  2         5                 manager                3
# 2                  3         5                 manager                4
# 3                  3         4       research director                3
# 4                  4         4         sales executive                1
# ...              ...       ...                     ...              ...
# 1673               4         1      research scientist                3
# 1674               3         5                 manager                3
# 1675               3         1      research scientist                4
# 1676               2         3  manufacturing director                2
# 1677               3         2      research scientist                3
#
#      maritalstatus  monthlyincome  monthlyrate  numcompaniesworked overtime  \
# 0              NaN       16280.83     42330.17                   7       No
# 1              NaN            NaN     43331.17                   0      NaN
# 2          married            NaN     41669.33                   1       No
# 3          married       14307.50     37199.50                   3      NaN
# 4         divorced       12783.92     33238.20                   2       No
# ...            ...            ...          ...                 ...      ...
# 1673        single        3949.17     10267.83                   4      NaN
# 1674       married       15943.72     41453.67                   3       No
# 1675           NaN            NaN      6090.75                   1       No
# 1676      divorced        8339.32     21682.23                   8      Yes
# 1677        single            NaN     11681.39                   4      Yes
#
#       percentsalaryhike  performancerating  relationshipsatisfaction  \
# 0                    13                3.0                         3
# 1                    14                3.0                         1
# 2                    11                3.0                         4
# 3                    19                3.0                         2
# 4                    12                3.0                         4
# ...                 ...                ...                       ...
# 1673                 12                3.0                         4
# 1674                 11                3.0                         3
# 1675                 19                3.0                         1
# 1676                 12                NaN                         3
# 1677                 14                3.0                         4
#
#      standardhours  stockoptionlevel  totalworkingyears  \
# 0        full time                 0                NaN
# 1        full time                 1               34.0
# 2        full time                 0               22.0
# 3        full time                 2                NaN
# 4        full time                 1                NaN
# ...            ...               ...                ...
# 1673     full time                 0                NaN
# 1674     full time                 1               27.0
# 1675     part time                 0                6.0
# 1676     part time                 1                NaN
# 1677     part time                 0               10.0
#
#       trainingtimeslastyear  worklifebalance  yearsatcompany  \
# 0                         5              3.0              20
# 1                         5              3.0              33
# 2                         3              NaN              22
# 3                         2              NaN              20
# 4                         5              3.0              19
# ...                     ...              ...             ...
# 1673                      2              3.0               3
# 1674                      2              3.0               5
# 1675                      1              3.0               6
# 1676                      4              3.0              22
# 1677                      2              3.0               8
#
#       yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                    NaN                       15                    15
# 1                    NaN                       11                     9
# 2                    NaN                       11                    15
# 3                    NaN                        5                     6
# 4                    NaN                        2                     8
# ...                  ...                      ...                   ...
# 1673                 NaN                        1                     2
# 1674                 NaN                        1                     0
# 1675                 NaN                        1                     5
# 1676                 NaN                       14                    10
# 1677                 NaN                        0                     7
#
#       sameasmonthlyincome  datebirth     salary  \
# 0                16280.83       1972  195370.00
# 1                     NaN       1971  199990.00
# 2                     NaN       1981  192320.00
# 3                14307.50       1976  171690.00
# 4                12783.92       1977        NaN
# ...                   ...        ...        ...
# 1673              3949.17       1980        NaN
# 1674             15943.72       1976  191324.62
# 1675                  NaN       1994   28111.13
# 1676              8339.32       1976  100071.84
# 1677                  NaN       1991   53914.11
#
#                          roledepartament  numberchildren remotework
# 0                                    NaN             NaN       True
# 1                                    NaN             NaN      False
# 2     manager  -  research & development             NaN      False
# 3                                    NaN             NaN      False
# 4                                    NaN             NaN       True
# ...                                  ...             ...        ...
# 1673                                 NaN             NaN       True
# 1674                                 NaN             NaN      False
# 1675                                 NaN             NaN      False
# 1676                                 NaN             NaN       True
# 1677                                 NaN             NaN       True
#
# [1678 rows x 40 columns]

# %%
df.to_csv("../datos/df_modificado.csv")
