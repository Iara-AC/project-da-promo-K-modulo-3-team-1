# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---

# %% [markdown]
# # Columnas Categoricas

# %%
df = pd.read_csv("../datos/hr_raw_data_final.csv", index_col = 0)

# %%
df.dtypes
# Out:
# age                          object
# attrition                    object
# businesstravel               object
# dailyrate                   float64
# department                   object
# distancefromhome              int64
# education                     int64
# educationfield               object
# employeecount                 int64
# employeenumber                int64
# environmentsatisfaction       int64
# gender                        int64
# hourlyrate                  float64
# jobinvolvement                int64
# joblevel                      int64
# jobrole                      object
# jobsatisfaction               int64
# maritalstatus                object
# monthlyincome                object
# monthlyrate                  object
# numcompaniesworked            int64
# over18                       object
# overtime                     object
# percentsalaryhike             int64
# performancerating            object
# relationshipsatisfaction      int64
# standardhours                object
# stockoptionlevel              int64
# totalworkingyears            object
# trainingtimeslastyear         int64
# worklifebalance              object
# yearsatcompany                int64
# yearsincurrentrole           object
# yearssincelastpromotion       int64
# yearswithcurrmanager          int64
# sameasmonthlyincome          object
# datebirth                     int64
# salary                       object
# roledepartament              object
# numberchildren              float64
# remotework                   object
# dtype: object

# %%
def buscar_columnas_categoricas(df):
    """
    Busca y devuelve las columnas de tipo categórico en un DataFrame.

    Parámetros:
    - df (pd.DataFrame): El DataFrame en el que se buscarán columnas categóricas.

    Retorna:
    - list: Lista de nombres de columnas que son de tipo categórico.
    """
    # Verifica si las columnas son del tipo 'category' o de tipo 'object' (usualmente usadas para categóricos)
    columnas_categoricas = df.select_dtypes(include=['O']).columns.tolist()
    return columnas_categoricas

# %%
print(f"Columnas categoricas: {buscar_columnas_categoricas(df)}")
# Out:
# Columnas categoricas: ['age', 'attrition', 'businesstravel', 'department', 'educationfield', 'jobrole', 'maritalstatus', 'monthlyincome', 'monthlyrate', 'over18', 'overtime', 'performancerating', 'standardhours', 'totalworkingyears', 'worklifebalance', 'yearsincurrentrole', 'sameasmonthlyincome', 'salary', 'roledepartament', 'remotework']

# %% [markdown]
# ---

# %% [markdown]
# # Transformación de los NAN

# %%
def transformar_nan_sql(df, columna=None, valor_reemplazo='NULL'):
    """
    Reemplaza los valores NaN en una columna específica o en todas las columnas 
    de un DataFrame con un valor compatible con SQL.

    Parámetros:
    - df (pd.DataFrame): El DataFrame en el que se reemplazarán los NaN.
    - columna (str, opcional): El nombre de la columna donde se reemplazarán los NaN. 
                               Si es None, reemplazará en todas las columnas.
    - valor_reemplazo: El valor con el que se reemplazarán los NaN. Ejemplo: 'NULL', '', 0.

    Retorna:
    - pd.DataFrame: El DataFrame con los NaN reemplazados.
    """
    if columna:
        # Si se especifica una columna, verifica que exista
        if columna not in df.columns:
            raise ValueError(f"La columna '{columna}' no existe en el DataFrame.")
        # Reemplaza los NaN en la columna específica
        df[columna] = df[columna].replace({np.nan: valor_reemplazo})
    else:
        # Reemplaza los NaN en todas las columnas
        df = df.replace({np.nan: valor_reemplazo})
    
    return df

# %%
# Reemplazar los NaN en una columna específica
transformar_nan_sql(df, columna="department", valor_reemplazo='NULL')
# Out:
#      age attrition businesstravel    dailyrate                department  \
# 0     51        No            NaN  2015.722222                      NULL
# 1     52        No            NaN  2063.388889                      NULL
# 2     42        No  travel_rarely  1984.253968   Research & Development
# 3     47        No  travel_rarely  1771.404762                      NULL
# 4     46        No            NaN  1582.771346                      NULL
# ...   ..       ...            ...          ...                       ...
# 1673  43        No            NaN   488.944444                      NULL
# 1674  47        No            NaN  1973.984127                      NULL
# 1675  29        No  travel_rarely   290.035510                      NULL
# 1676  47        No  travel_rarely  1032.487286                      NULL
# 1677  32        No            NaN   556.256661                      NULL
#
#       distancefromhome  education    educationfield  employeecount  \
# 0                    6          3               NaN              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1673               -26          3           Medical              1
# 1674                26          4               NaN              1
# 1675                15          3               NaN              1
# 1676                 4          3     Life Sciences              1
# 1677                 2          2     Life Sciences              1
#
#       employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0                  1                        1       0         NaN
# 1                  2                        3       0         NaN
# 2                  3                        3       0         NaN
# 3                  4                        1       1         NaN
# 4                  5                        1       1         NaN
# ...              ...                      ...     ...         ...
# 1673             824                        2       1         NaN
# 1674            1087                        4       1         NaN
# 1675             528                        3       0         NaN
# 1676              76                        3       1         NaN
# 1677             401                        4       1   69.532083
#
#       jobinvolvement  joblevel                   jobrole  jobsatisfaction  \
# 0                  3         5        resEArch DIREcToR                 3
# 1                  2         5                  ManAGeR                 3
# 2                  3         5                  ManaGER                 4
# 3                  3         4        ReseArCH DIrECtOr                 3
# 4                  4         4          sAleS EXECUtIve                 1
# ...              ...       ...                       ...              ...
# 1673               4         1       rESEaRcH SciEnTiST                 3
# 1674               3         5                  mANager                 3
# 1675               3         1       reSearch sCienTiSt                 4
# 1676               2         3   maNufACTURING DIREctOr                 2
# 1677               3         2       resEArch scIENTisT                 3
#
#      maritalstatus monthlyincome monthlyrate  numcompaniesworked over18  \
# 0              NaN     16280,83$   42330,17$                   7      Y
# 1              NaN           NaN   43331,17$                   0    NaN
# 2          Married           NaN   41669,33$                   1    NaN
# 3          Married     14307,50$   37199,50$                   3      Y
# 4         Divorced     12783,92$   33238,20$                   2      Y
# ...            ...           ...         ...                 ...    ...
# 1673        Single      3949,17$   10267,83$                   4    NaN
# 1674       Married     15943,72$   41453,67$                   3      Y
# 1675           NaN           NaN    6090,75$                   1    NaN
# 1676      Divorced      8339,32$   21682,23$                   8    NaN
# 1677        Single           NaN   11681,39$                   4      Y
#
#      overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# 0          No                 13               3,0                         3
# 1         NaN                 14               3,0                         1
# 2          No                 11               3,0                         4
# 3         NaN                 19               3,0                         2
# 4          No                 12               3,0                         4
# ...       ...                ...               ...                       ...
# 1673      NaN                 12               3,0                         4
# 1674       No                 11               3,0                         3
# 1675       No                 19               3,0                         1
# 1676      Yes                 12               NaN                         3
# 1677      Yes                 14               3,0                         4
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0        Full Time                 0               NaN                      5
# 1              NaN                 1              34,0                      5
# 2              NaN                 0              22,0                      3
# 3        Full Time                 2               NaN                      2
# 4              NaN                 1               NaN                      5
# ...            ...               ...               ...                    ...
# 1673           NaN                 0               NaN                      2
# 1674     Full Time                 1              27,0                      2
# 1675     Part Time                 0               6,0                      1
# 1676     Part Time                 1               NaN                      4
# 1677     Part Time                 0              10,0                      2
#
#      worklifebalance  yearsatcompany yearsincurrentrole  \
# 0                3,0              20                NaN
# 1                3,0              33                NaN
# 2                NaN              22                NaN
# 3                NaN              20                NaN
# 4                3,0              19                NaN
# ...              ...             ...                ...
# 1673             3,0               3                NaN
# 1674             3,0               5                NaN
# 1675             3,0               6                NaN
# 1676             3,0              22                NaN
# 1677             3,0               8                NaN
#
#       yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# 0                          15                    15           16280,83$
# 1                          11                     9                 NaN
# 2                          11                    15                 NaN
# 3                           5                     6           14307,50$
# 4                           2                     8           12783,92$
# ...                       ...                   ...                 ...
# 1673                        1                     2            3949,17$
# 1674                        1                     0           15943,72$
# 1675                        1                     5                 NaN
# 1676                       14                    10            8339,32$
# 1677                        0                     7                 NaN
#
#       datebirth      salary                       roledepartament  \
# 0          1972  195370,00$                                   NaN
# 1          1971  199990,00$                                   NaN
# 2          1981  192320,00$   ManaGER  -  Research & Development
# 3          1976  171690,00$                                   NaN
# 4          1977         NaN                                   NaN
# ...         ...         ...                                   ...
# 1673       1980         NaN                                   NaN
# 1674       1976  191324,62$                                   NaN
# 1675       1994   28111,13$                                   NaN
# 1676       1976  100071,84$                                   NaN
# 1677       1991   53914,11$                                   NaN
#
#       numberchildren remotework
# 0                NaN        Yes
# 1                NaN          1
# 2                NaN          1
# 3                NaN      False
# 4                NaN          0
# ...              ...        ...
# 1673             NaN        Yes
# 1674             NaN      False
# 1675             NaN      False
# 1676             NaN        Yes
# 1677             NaN          0
#
# [1678 rows x 41 columns]

# %%
# Reemplazar los NaN en todas las columnas
transformar_nan_sql(df, valor_reemplazo='NULL')
# Out:
#      age attrition businesstravel    dailyrate                department  \
# 0     51        No           NULL  2015.722222                      NULL
# 1     52        No           NULL  2063.388889                      NULL
# 2     42        No  travel_rarely  1984.253968   Research & Development
# 3     47        No  travel_rarely  1771.404762                      NULL
# 4     46        No           NULL  1582.771346                      NULL
# ...   ..       ...            ...          ...                       ...
# 1673  43        No           NULL   488.944444                      NULL
# 1674  47        No           NULL  1973.984127                      NULL
# 1675  29        No  travel_rarely   290.035510                      NULL
# 1676  47        No  travel_rarely  1032.487286                      NULL
# 1677  32        No           NULL   556.256661                      NULL
#
#       distancefromhome  education    educationfield  employeecount  \
# 0                    6          3              NULL              1
# 1                    1          4     Life Sciences              1
# 2                    4          2  Technical Degree              1
# 3                    2          4           Medical              1
# 4                    3          3  Technical Degree              1
# ...                ...        ...               ...            ...
# 1673               -26          3           Medical              1
# 1674                26          4              NULL              1
# 1675                15          3              NULL              1
# 1676                 4          3     Life Sciences              1
# 1677                 2          2     Life Sciences              1
#
#       employeenumber  environmentsatisfaction  gender hourlyrate  \
# 0                  1                        1       0       NULL
# 1                  2                        3       0       NULL
# 2                  3                        3       0       NULL
# 3                  4                        1       1       NULL
# 4                  5                        1       1       NULL
# ...              ...                      ...     ...        ...
# 1673             824                        2       1       NULL
# 1674            1087                        4       1       NULL
# 1675             528                        3       0       NULL
# 1676              76                        3       1       NULL
# 1677             401                        4       1  69.532083
#
#       jobinvolvement  joblevel                   jobrole  jobsatisfaction  \
# 0                  3         5        resEArch DIREcToR                 3
# 1                  2         5                  ManAGeR                 3
# 2                  3         5                  ManaGER                 4
# 3                  3         4        ReseArCH DIrECtOr                 3
# 4                  4         4          sAleS EXECUtIve                 1
# ...              ...       ...                       ...              ...
# 1673               4         1       rESEaRcH SciEnTiST                 3
# 1674               3         5                  mANager                 3
# 1675               3         1       reSearch sCienTiSt                 4
# 1676               2         3   maNufACTURING DIREctOr                 2
# 1677               3         2       resEArch scIENTisT                 3
#
#      maritalstatus monthlyincome monthlyrate  numcompaniesworked over18  \
# 0             NULL     16280,83$   42330,17$                   7      Y
# 1             NULL          NULL   43331,17$                   0   NULL
# 2          Married          NULL   41669,33$                   1   NULL
# 3          Married     14307,50$   37199,50$                   3      Y
# 4         Divorced     12783,92$   33238,20$                   2      Y
# ...            ...           ...         ...                 ...    ...
# 1673        Single      3949,17$   10267,83$                   4   NULL
# 1674       Married     15943,72$   41453,67$                   3      Y
# 1675          NULL          NULL    6090,75$                   1   NULL
# 1676      Divorced      8339,32$   21682,23$                   8   NULL
# 1677        Single          NULL   11681,39$                   4      Y
#
#      overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# 0          No                 13               3,0                         3
# 1        NULL                 14               3,0                         1
# 2          No                 11               3,0                         4
# 3        NULL                 19               3,0                         2
# 4          No                 12               3,0                         4
# ...       ...                ...               ...                       ...
# 1673     NULL                 12               3,0                         4
# 1674       No                 11               3,0                         3
# 1675       No                 19               3,0                         1
# 1676      Yes                 12              NULL                         3
# 1677      Yes                 14               3,0                         4
#
#      standardhours  stockoptionlevel totalworkingyears  trainingtimeslastyear  \
# 0        Full Time                 0              NULL                      5
# 1             NULL                 1              34,0                      5
# 2             NULL                 0              22,0                      3
# 3        Full Time                 2              NULL                      2
# 4             NULL                 1              NULL                      5
# ...            ...               ...               ...                    ...
# 1673          NULL                 0              NULL                      2
# 1674     Full Time                 1              27,0                      2
# 1675     Part Time                 0               6,0                      1
# 1676     Part Time                 1              NULL                      4
# 1677     Part Time                 0              10,0                      2
#
#      worklifebalance  yearsatcompany yearsincurrentrole  \
# 0                3,0              20               NULL
# 1                3,0              33               NULL
# 2               NULL              22               NULL
# 3               NULL              20               NULL
# 4                3,0              19               NULL
# ...              ...             ...                ...
# 1673             3,0               3               NULL
# 1674             3,0               5               NULL
# 1675             3,0               6               NULL
# 1676             3,0              22               NULL
# 1677             3,0               8               NULL
#
#       yearssincelastpromotion  yearswithcurrmanager sameasmonthlyincome  \
# 0                          15                    15           16280,83$
# 1                          11                     9                NULL
# 2                          11                    15                NULL
# 3                           5                     6           14307,50$
# 4                           2                     8           12783,92$
# ...                       ...                   ...                 ...
# 1673                        1                     2            3949,17$
# 1674                        1                     0           15943,72$
# 1675                        1                     5                NULL
# 1676                       14                    10            8339,32$
# 1677                        0                     7                NULL
#
#       datebirth      salary                       roledepartament  \
# 0          1972  195370,00$                                  NULL
# 1          1971  199990,00$                                  NULL
# 2          1981  192320,00$   ManaGER  -  Research & Development
# 3          1976  171690,00$                                  NULL
# 4          1977        NULL                                  NULL
# ...         ...         ...                                   ...
# 1673       1980        NULL                                  NULL
# 1674       1976  191324,62$                                  NULL
# 1675       1994   28111,13$                                  NULL
# 1676       1976  100071,84$                                  NULL
# 1677       1991   53914,11$                                  NULL
#
#      numberchildren remotework
# 0              NULL        Yes
# 1              NULL          1
# 2              NULL          1
# 3              NULL      False
# 4              NULL          0
# ...             ...        ...
# 1673           NULL        Yes
# 1674           NULL      False
# 1675           NULL      False
# 1676           NULL        Yes
# 1677           NULL          0
#
# [1678 rows x 41 columns]

# %%
df.head(2)
# Out:
#   age attrition businesstravel    dailyrate department  distancefromhome  \
# 0  51        No            NaN  2015.722222       NULL                 6
# 1  52        No            NaN  2063.388889       NULL                 1
#
#    education educationfield  employeecount  employeenumber  \
# 0          3            NaN              1               1
# 1          4  Life Sciences              1               2
#
#    environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 0                        1       0         NaN               3         5
# 1                        3       0         NaN               2         5
#
#                jobrole  jobsatisfaction maritalstatus monthlyincome  \
# 0   resEArch DIREcToR                 3           NaN     16280,83$
# 1             ManAGeR                 3           NaN           NaN
#
#   monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# 0   42330,17$                   7      Y       No                 13
# 1   43331,17$                   0    NaN      NaN                 14
#
#   performancerating  relationshipsatisfaction standardhours  stockoptionlevel  \
# 0               3,0                         3     Full Time                 0
# 1               3,0                         1           NaN                 1
#
#   totalworkingyears  trainingtimeslastyear worklifebalance  yearsatcompany  \
# 0               NaN                      5             3,0              20
# 1              34,0                      5             3,0              33
#
#   yearsincurrentrole  yearssincelastpromotion  yearswithcurrmanager  \
# 0                NaN                       15                    15
# 1                NaN                       11                     9
#
#   sameasmonthlyincome  datebirth      salary roledepartament  numberchildren  \
# 0           16280,83$       1972  195370,00$             NaN             NaN
# 1                 NaN       1971  199990,00$             NaN             NaN
#
#   remotework
# 0        Yes
# 1          1

# %%
# Crear función de conversión de números a numeros absolutos

def convertir_a_absoluto(numero):
    """
    Convierte un número a su valor absoluto.

    Parámetros:
    numero (int | float): Número a convertir.

    Retorno:
    int | float: Valor absoluto del número.
    """
    return abs(numero)

# Ejemplo de uso
print(convertir_a_absoluto(-5))      
print(convertir_a_absoluto(-3.14))
# Out:
# 5
# 3.14

# %%
# Crear función para transformar float a string

def float_a_string(dato):
    """
    Convierte un número float a string.
    
    Parámetros:
    dato (float): Número a convertir.
    
    Retorno:
    str: Representación del número en formato string.
    """
    return str(dato)

# Ejemplo de uso
resultado = float_a_string(123.456)
print(resultado)
# Out:
# 123.456

# %%
type(resultado)
# Out:
# str

# %%
# Crear función para transformar string a int. No esta hecho para las columnas adecuadas. 

def string_a_int (dato):
    try:
        return int (dato)
    except:
        return np.nan
columns = ['age', 'monthlyincome','monthlyrate','yearsincurrentrole', 'salary']
for col in columns:
    df[col] = df[col].apply(string_a_int)

# Ejemplo de uso
df['age']
# Out:
# 0       51.0
# 1       52.0
# 2       42.0
# 3       47.0
# 4       46.0
#         ...
# 1673    43.0
# 1674    47.0
# 1675    29.0
# 1676    47.0
# 1677    32.0
# Name: age, Length: 1678, dtype: float64

# %%
def cambiar_coma_punto(columna):
    """
    Cambia las comas por puntos y elimina símbolos como '$' en los valores de una columna.
    Parámetros:
        columna (str): Cadena de texto a modificar.
    Retorna:
        float: Número transformado, o np.nan si ocurre un error.
    """
    if isinstance(columna, (int, float)):
            return columna
    try:
        # Reemplazar comas por puntos y eliminar el símbolo '$'
        return float(columna.replace(',', '.').replace('$', ''))
    except:
        # Si hay un error (como valores no numéricos), devolver NaN
        return np.nan
columnas = ["totalworkingyears", "worklifebalance", "yearsincurrentrole", "monthlyincome", "monthlyrate", "sameasmonthlyincome", "salary"]
# Aplicar la transformación
for col in columnas:
    if col in df.columns:
        df[col] = df[col].apply(cambiar_coma_punto)
df.head(30)
# Out:
#      age attrition     businesstravel    dailyrate                department  \
# 0   51.0        No                NaN  2015.722222                      NULL
# 1   52.0        No                NaN  2063.388889                      NULL
# 2   42.0        No      travel_rarely  1984.253968   Research & Development
# 3   47.0        No      travel_rarely  1771.404762                      NULL
# 4   46.0        No                NaN  1582.771346                      NULL
# 5   48.0        No                NaN  1771.920635   Research & Development
# 6   59.0        No                NaN  1032.487286                      NULL
# 7   42.0        No      travel_rarely   556.256661                      NULL
# 8   41.0        No                NaN  1712.182540                      NULL
# 9   41.0        No  travel_frequently  1973.984127                      NULL
# 10  41.0        No         non-travel  2060.706349                      NULL
# 11  56.0        No      travel_rarely  1382.746032                      NULL
# 12  38.0        No                NaN  1362.523810                      NULL
# 13  41.0       Yes      travel_rarely  2016.547619                      NULL
# 14  55.0        No                NaN  1973.984127                      NULL
# 15  40.0        No      travel_rarely  1861.373016                      NULL
# 16  58.0       Yes      travel_rarely  1985.698413                      NULL
# 17  46.0        No      travel_rarely  1582.771346                      NULL
# 18  35.0        No                NaN   556.256661                      NULL
# 19  40.0        No      travel_rarely  1032.487286                      NULL
# 20  45.0        No         non-travel  1108.920635   Research & Development
# 21  33.0        No                NaN  1032.487286                      NULL
# 22  36.0        No                NaN  1032.487286                      NULL
# 23  47.0        No                NaN  1728.380952                      NULL
# 24  36.0        No      travel_rarely   639.785714                      NULL
# 25  35.0        No                NaN  1032.487286                      NULL
# 26  52.0       Yes                NaN  2047.500000                      NULL
# 27  36.0        No                NaN   556.256661                      NULL
# 28  33.0        No      travel_rarely   556.256661                      NULL
# 29  34.0        No         non-travel   412.801587                    Sales
#
#     distancefromhome  education    educationfield  employeecount  \
# 0                  6          3               NaN              1
# 1                  1          4     Life Sciences              1
# 2                  4          2  Technical Degree              1
# 3                  2          4           Medical              1
# 4                  3          3  Technical Degree              1
# 5                 22          3           Medical              1
# 6                 25          3     Life Sciences              1
# 7                  1          1               NaN              1
# 8                  2          5               NaN              1
# 9                  9          3               NaN              1
# 10                 7          1               NaN              1
# 11                23          3     Life Sciences              1
# 12                10          3           Medical              1
# 13                12          3               NaN              1
# 14                14          4           Medical              1
# 15                 2          4               NaN              1
# 16                 2          4               NaN              1
# 17                 2          3               NaN              1
# 18               -13          5     Life Sciences              1
# 19                15          3     Life Sciences              1
# 20                 1          1               NaN              1
# 21                 1          2     Life Sciences              1
# 22                 8          3               NaN              1
# 23                 2          2             Other              1
# 24               -42          2     Life Sciences              1
# 25                 9          3     Life Sciences              1
# 26                 2          1               NaN              1
# 27                 2          4     Life Sciences              1
# 28                28          4     Life Sciences              1
# 29                10          3     Life Sciences              1
#
#     employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0                1                        1       0         NaN
# 1                2                        3       0         NaN
# 2                3                        3       0         NaN
# 3                4                        1       1         NaN
# 4                5                        1       1         NaN
# 5                6                        4       1         NaN
# 6                7                        1       1         NaN
# 7                8                        2       0   69.532083
# 8                9                        2       1         NaN
# 9               10                        1       0         NaN
# 10              11                        2       1         NaN
# 11              12                        4       0  172.843254
# 12              13                        2       1         NaN
# 13              14                        2       1         NaN
# 14              15                        3       0         NaN
# 15              16                        3       1         NaN
# 16              17                        4       0         NaN
# 17              18                        3       1         NaN
# 18              19                        2       0         NaN
# 19              20                        1       1         NaN
# 20              21                        3       0         NaN
# 21              22                        1       1         NaN
# 22              23                        3       1         NaN
# 23              24                        3       1  216.047619
# 24              25                        4       0   79.973214
# 25              26                        4       1  129.060911
# 26              27                        1       1         NaN
# 27              28                        3       1         NaN
# 28              29                        2       0   69.532083
# 29              30                        4       0         NaN
#
#     jobinvolvement  joblevel                      jobrole  jobsatisfaction  \
# 0                3         5           resEArch DIREcToR                 3
# 1                2         5                     ManAGeR                 3
# 2                3         5                     ManaGER                 4
# 3                3         4           ReseArCH DIrECtOr                 3
# 4                4         4             sAleS EXECUtIve                 1
# 5                3         4                     MANAger                 4
# 6                3         3             Sales ExeCutIVe                 1
# 7                3         2             Sales eXEcUTiVe                 3
# 8                3         4                     mANAGEr                 1
# 9                3         5           reSEaRCH DIrectoR                 3
# 10               1         5           RESeArcH DIrEctoR                 3
# 11               3         4      MANUfACturing DIReCtOr                 2
# 12               1         3           REseaRCh dirEcToR                 3
# 13               3         5           reseARCh DIrEctoR                 3
# 14               4         5           RESeaRCH dirEctor                 2
# 15               3         5                     MAnAgeR                 3
# 16               3         5           reSeARCh DIrEcToR                 2
# 17               3         4                     MAnaGER                 1
# 18               4         2          REseArcH sciENtiST                 1
# 19               2         3      MAnUFaCtUring dIRecTOr                 3
# 20               2         3   heaLtHcArE repResENtATiVe                 3
# 21               3         3           RESEARCH dIrECtor                 4
# 22               3         3   hEaltHCarE ReprESENTAtIvE                 3
# 23               3         4                     maNagEr                 4
# 24               3         2             SALEs exeCUtIVe                 4
# 25               2         3      manUfACtURing dirEctOR                 3
# 26               1         5                     mAnageR                 4
# 27               3         2      MaNufActURing dIrecTOr                 2
# 28               3         2       laBoratOry tecHNiCiaN                 3
# 29               3         2             saLEs exEcutIVe                 3
#
#    maritalstatus  monthlyincome  monthlyrate  numcompaniesworked over18  \
# 0            NaN            NaN          NaN                   7      Y
# 1            NaN            NaN          NaN                   0    NaN
# 2        Married            NaN          NaN                   1    NaN
# 3        Married            NaN          NaN                   3      Y
# 4       Divorced            NaN          NaN                   2      Y
# 5            NaN            NaN          NaN                   3    NaN
# 6            NaN            NaN          NaN                   7      Y
# 7        Married            NaN          NaN                   1    NaN
# 8        Married            NaN          NaN                   7    NaN
# 9            NaN            NaN          NaN                   2    NaN
# 10           NaN            NaN          NaN                   1      Y
# 11       Married            NaN          NaN                   4    NaN
# 12       Married            NaN          NaN                   3      Y
# 13       Married            NaN          NaN                   1    NaN
# 14        Single            NaN          NaN                   8    NaN
# 15           NaN            NaN          NaN                   0    NaN
# 16        Single            NaN          NaN                   7      Y
# 17           NaN            NaN          NaN                   8    NaN
# 18       Married            NaN          NaN                   1    NaN
# 19           NaN            NaN          NaN                   1      Y
# 20           NaN            NaN          NaN                   3      Y
# 21        Single            NaN          NaN                   1    NaN
# 22      Divorced            NaN          NaN                   1      Y
# 23       Married            NaN          NaN                   1    NaN
# 24           NaN            NaN          NaN                   1      Y
# 25       Married            NaN          NaN                   1      Y
# 26       Married            NaN          NaN                   1      Y
# 27        Single            NaN          NaN                   9      Y
# 28       Married            NaN          NaN                   1      Y
# 29           NaN            NaN          NaN                   1      Y
#
#    overtime  percentsalaryhike performancerating  relationshipsatisfaction  \
# 0        No                 13               3,0                         3
# 1       NaN                 14               3,0                         1
# 2        No                 11               3,0                         4
# 3       NaN                 19               3,0                         2
# 4        No                 12               3,0                         4
# 5        No                 11               3,0                         2
# 6       NaN                 11               3,0                         4
# 7        No                 25               4,0                         3
# 8        No                 16               3,0                         2
# 9        No                 17               3,0                         2
# 10       No                 22               4,0                         2
# 11      Yes                 12               NaN                         1
# 12       No                 12               3,0                         1
# 13       No                 12               3,0                         4
# 14       No                 11               3,0                         4
# 15       No                 14               3,0                         4
# 16      Yes                 12               3,0                         4
# 17      NaN                 23               4,0                         1
# 18      NaN                 11               3,0                         4
# 19      NaN                 13               3,0                         4
# 20      NaN                 23               4,0                         4
# 21      Yes                 12               3,0                         3
# 22      NaN                 13               NaN                         2
# 23      NaN                 11               3,0                         3
# 24      NaN                 14               3,0                         4
# 25      Yes                 20               4,0                         2
# 26       No                 15               3,0                         4
# 27      Yes                 11               3,0                         4
# 28      NaN                 12               3,0                         2
# 29      Yes                 14               3,0                         3
#
#    standardhours  stockoptionlevel  totalworkingyears  trainingtimeslastyear  \
# 0      Full Time                 0                NaN                      5
# 1            NaN                 1                NaN                      5
# 2            NaN                 0                NaN                      3
# 3      Full Time                 2                NaN                      2
# 4            NaN                 1                NaN                      5
# 5            NaN                 1                NaN                      3
# 6      Part Time                 0                NaN                      3
# 7      Part Time                 0                NaN                      3
# 8      Full Time                 1                NaN                      2
# 9            NaN                 1                NaN                      2
# 10     Full Time                 2                NaN                      3
# 11     Full Time                 1                NaN                      0
# 12     Full Time                 1                NaN                      3
# 13     Full Time                 0                NaN                      0
# 14           NaN                 0                NaN                      3
# 15     Full Time                 0                NaN                      2
# 16     Full Time                 0                NaN                      2
# 17           NaN                 0                NaN                      2
# 18           NaN                 0                NaN                      2
# 19           NaN                 2                NaN                      2
# 20     Full Time                 1                NaN                      3
# 21     Part Time                 0                NaN                      1
# 22           NaN                 3                NaN                      2
# 23     Full Time                 1                NaN                      3
# 24     Full Time                 1                NaN                      1
# 25     Part Time                 1                NaN                      2
# 26     Full Time                 1                NaN                      3
# 27           NaN                 0                NaN                      2
# 28     Part Time                 1                NaN                      3
# 29     Part Time                 1                NaN                      3
#
#     worklifebalance  yearsatcompany  yearsincurrentrole  \
# 0               NaN              20                 NaN
# 1               NaN              33                 NaN
# 2               NaN              22                 NaN
# 3               NaN              20                 NaN
# 4               NaN              19                 NaN
# 5               NaN              22                 NaN
# 6               NaN              21                 NaN
# 7               NaN              20                 NaN
# 8               NaN              18                 NaN
# 9               NaN              18                 NaN
# 10              NaN              21                 NaN
# 11              NaN              19                 NaN
# 12              NaN              18                 NaN
# 13              NaN              22                 NaN
# 14              NaN              24                 NaN
# 15              NaN              20                 NaN
# 16              NaN              31                 NaN
# 17              NaN              26                 NaN
# 18              NaN              16                 NaN
# 19              NaN              18                 NaN
# 20              NaN              23                 NaN
# 21              NaN              15                 NaN
# 22              NaN              17                 NaN
# 23              NaN              26                 NaN
# 24              NaN              18                 NaN
# 25              NaN              17                 NaN
# 26              NaN              32                 NaN
# 27              NaN              16                 NaN
# 28              NaN              15                 NaN
# 29              NaN              15                 NaN
#
#     yearssincelastpromotion  yearswithcurrmanager  sameasmonthlyincome  \
# 0                        15                    15                  NaN
# 1                        11                     9                  NaN
# 2                        11                    15                  NaN
# 3                         5                     6                  NaN
# 4                         2                     8                  NaN
# 5                         4                     7                  NaN
# 6                         7                     9                  NaN
# 7                        11                     6                  NaN
# 8                        11                     8                  NaN
# 9                         0                    11                  NaN
# 10                        5                    10                  NaN
# 11                       15                     9                  NaN
# 12                        1                    11                  NaN
# 13                       15                     8                  NaN
# 14                        2                    15                  NaN
# 15                        1                    12                  NaN
# 16                       13                     8                  NaN
# 17                       15                     9                  NaN
# 18                        1                    10                  NaN
# 19                       14                    12                  NaN
# 20                       14                     4                  NaN
# 21                        8                    12                  NaN
# 22                       12                     8                  NaN
# 23                        3                     0                  NaN
# 24                        4                    11                  NaN
# 25                        5                    15                  NaN
# 26                        6                     9                  NaN
# 27                        5                    12                  NaN
# 28                        5                     7                  NaN
# 29                        0                     7                  NaN
#
#     datebirth  salary                                    roledepartament  \
# 0        1972     NaN                                                NaN
# 1        1971     NaN                                                NaN
# 2        1981     NaN                ManaGER  -  Research & Development
# 3        1976     NaN                                                NaN
# 4        1977     NaN                                                NaN
# 5        1975     NaN                MANAger  -  Research & Development
# 6        1964     NaN                                                NaN
# 7        1981     NaN                                                NaN
# 8        1982     NaN                                                NaN
# 9        1982     NaN                                                NaN
# 10       1982     NaN                                                NaN
# 11       1967     NaN                                                NaN
# 12       1985     NaN                                                NaN
# 13       1982     NaN                                                NaN
# 14       1968     NaN                                                NaN
# 15       1983     NaN                                                NaN
# 16       1965     NaN                                                NaN
# 17       1977     NaN                                                NaN
# 18       1988     NaN                                                NaN
# 19       1983     NaN                                                NaN
# 20       1978     NaN   heaLtHcArE repResENtATiVe  -  Research & Deve...
# 21       1990     NaN                                                NaN
# 22       1987     NaN                                                NaN
# 23       1976     NaN                                                NaN
# 24       1987     NaN                                                NaN
# 25       1988     NaN                                                NaN
# 26       1971     NaN                                                NaN
# 27       1987     NaN                                                NaN
# 28       1990     NaN                                                NaN
# 29       1989     NaN                         saLEs exEcutIVe  -  Sales
#
#     numberchildren remotework
# 0              NaN        Yes
# 1              NaN          1
# 2              NaN          1
# 3              NaN      False
# 4              NaN          0
# 5              NaN        Yes
# 6              NaN       True
# 7              NaN          0
# 8              NaN       True
# 9              NaN          0
# 10             NaN          0
# 11             NaN      False
# 12             NaN          1
# 13             NaN      False
# 14             NaN       True
# 15             NaN          0
# 16             NaN          0
# 17             NaN      False
# 18             NaN      False
# 19             NaN       True
# 20             NaN      False
# 21             NaN       True
# 22             NaN          1
# 23             NaN      False
# 24             NaN       True
# 25             NaN      False
# 26             NaN          1
# 27             NaN          0
# 28             NaN        Yes
# 29             NaN          1

# %%
type(resultado2)
# Out:
# float

# %%
# Quedarse con el Primer Dígito de un Número de Dos Dígitos:
def primer_digito(df, column):
    df[column] = df[column].astype(str).str[0].astype(int)
    return df
# Uso:
df = primer_digito(df, 'environmentsatisfaction')

# %%
df['environmentsatisfaction'].unique()
# Out:
# array([1, 3, 4, 2])
